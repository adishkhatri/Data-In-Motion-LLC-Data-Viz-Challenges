# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("Orgnostic_ People Analytics Dataset.xlsx - Employees.csv")
df
# Out:
#      Employee ID           Department                Team Location  \
# 0           1001           Operations             Biz Ops      USA
# 1           1002           Operations             Biz Ops      USA
# 2           1003           Operations          Compliance      USA
# 3           1004           Operations          Compliance      USA
# 4           1005           Operations  Talent Acquisition      USA
# ..           ...                  ...                 ...      ...
# 205         5024  Customer Experience             Success    Spain
# 206         5025  Customer Experience             Support      USA
# 207         5026  Customer Experience             Support    Spain
# 208         5027  Customer Experience             Support    Spain
# 209         5028  Customer Experience             Success    Spain
#
#       Hire Date Termination Date           Termination Type
# 0      2/1/2019              NaN                        NaN
# ...

# %%
df['Active']=df['Termination Date']

# %%
df
# Out:
#      Employee ID           Department                Team Location  \
# 0           1001           Operations             Biz Ops      USA
# 1           1002           Operations             Biz Ops      USA
# 2           1003           Operations          Compliance      USA
# 3           1004           Operations          Compliance      USA
# 4           1005           Operations  Talent Acquisition      USA
# ..           ...                  ...                 ...      ...
# 205         5024  Customer Experience             Success    Spain
# 206         5025  Customer Experience             Support      USA
# 207         5026  Customer Experience             Support    Spain
# 208         5027  Customer Experience             Support    Spain
# 209         5028  Customer Experience             Success    Spain
#
#       Hire Date Termination Date           Termination Type     Active
# 0      2/1/2019              NaN                        NaN        NaN
# ...

# %%
df['Active']=df['Active'].fillna(1)
df
# Out:
#      Employee ID           Department                Team Location  \
# 0           1001           Operations             Biz Ops      USA
# 1           1002           Operations             Biz Ops      USA
# 2           1003           Operations          Compliance      USA
# 3           1004           Operations          Compliance      USA
# 4           1005           Operations  Talent Acquisition      USA
# ..           ...                  ...                 ...      ...
# 205         5024  Customer Experience             Success    Spain
# 206         5025  Customer Experience             Support      USA
# 207         5026  Customer Experience             Support    Spain
# 208         5027  Customer Experience             Support    Spain
# 209         5028  Customer Experience             Success    Spain
#
#       Hire Date Termination Date           Termination Type     Active
# 0      2/1/2019              NaN                        NaN          1
# ...

# %%
df['Active']=df['Active'].apply(lambda x:0 if x!=1 else 1)

# %%
df
# Out:
#      Employee ID           Department                Team Location  \
# 0           1001           Operations             Biz Ops      USA
# 1           1002           Operations             Biz Ops      USA
# 2           1003           Operations          Compliance      USA
# 3           1004           Operations          Compliance      USA
# 4           1005           Operations  Talent Acquisition      USA
# ..           ...                  ...                 ...      ...
# 205         5024  Customer Experience             Success    Spain
# 206         5025  Customer Experience             Support      USA
# 207         5026  Customer Experience             Support    Spain
# 208         5027  Customer Experience             Support    Spain
# 209         5028  Customer Experience             Success    Spain
#
#       Hire Date Termination Date           Termination Type  Active
# 0      2/1/2019              NaN                        NaN       1
# ...

# %%
df.isnull().sum()
# Out:
# Employee ID           0
# Department            0
# Team                  0
# Location              0
# Hire Date             0
# Termination Date    185
# Termination Type    185
# Active                0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 210 entries, 0 to 209
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Employee ID       210 non-null    int64
#  1   Department        210 non-null    object
#  2   Team              210 non-null    object
#  3   Location          210 non-null    object
#  4   Hire Date         210 non-null    object
#  5   Termination Date  25 non-null     object
#  6   Termination Type  25 non-null     object
#  7   Active            210 non-null    int64
# dtypes: int64(2), object(6)
# memory usage: 13.2+ KB

# %%
df['Hire Date']=pd.to_datetime(df['Hire Date'])
df['Termination Date']=pd.to_datetime(df['Termination Date'])
df
# Out:
#      Employee ID           Department                Team Location  Hire Date  \
# 0           1001           Operations             Biz Ops      USA 2019-02-01
# 1           1002           Operations             Biz Ops      USA 2019-02-15
# 2           1003           Operations          Compliance      USA 2019-02-15
# 3           1004           Operations          Compliance      USA 2019-05-02
# 4           1005           Operations  Talent Acquisition      USA 2019-03-18
# ..           ...                  ...                 ...      ...        ...
# 205         5024  Customer Experience             Success    Spain 2021-04-15
# 206         5025  Customer Experience             Support      USA 2021-08-20
# 207         5026  Customer Experience             Support    Spain 2021-05-03
# 208         5027  Customer Experience             Support    Spain 2021-03-10
# 209         5028  Customer Experience             Success    Spain 2020-11-30
#
# ...

# %%
df.to_csv('people_analytic_2_cleaned.csv',index=False)
