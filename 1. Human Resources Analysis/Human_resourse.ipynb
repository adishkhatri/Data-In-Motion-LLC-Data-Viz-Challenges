# %%
import pandas as pd

# %%
df = pd.read_csv("Human Resources.csv")
df
# Out:
#                id first_name    last_name  birthdate  gender  \
# 0      00-0037846      Kimmy   Walczynski   6/4/1991    Male
# 1      00-0041533   Ignatius    Springett  6/29/1984    Male
# 2      00-0045747     Corbie  Bittlestone  7/29/1989    Male
# 3      00-0055274       Baxy       Matton  9/14/1982  Female
# 4      00-0076100    Terrell         Suff  4/11/1994  Female
# ...           ...        ...          ...        ...     ...
# 37403         NaN        NaN          NaN        NaN     NaN
# 37404         NaN        NaN          NaN        NaN     NaN
# 37405         NaN        NaN          NaN        NaN     NaN
# 37406         NaN        NaN          NaN        NaN     NaN
# 37407         NaN        NaN          NaN        NaN     NaN
#
#                             race            department  \
# 0             Hispanic or Latino           Engineering
# 1                          White  Business Development
# 2      Black or African American                 Sales
# ...

# %%
df.isnull().sum()
# Out:
# id                15194
# first_name        15194
# last_name         15194
# birthdate         15194
# gender            15194
# race              15194
# department        15194
# jobtitle          15141
# location          15194
# hire_date         15194
# termdate          33479
# location_city     15194
# location_state    15194
# dtype: int64

# %%
df = df.dropna(subset=['id'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22214 entries, 0 to 22213
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              22214 non-null  object
#  1   first_name      22214 non-null  object
#  2   last_name       22214 non-null  object
#  3   birthdate       22214 non-null  object
#  4   gender          22214 non-null  object
#  5   race            22214 non-null  object
#  6   department      22214 non-null  object
#  7   jobtitle        22214 non-null  object
#  8   location        22214 non-null  object
#  9   hire_date       22214 non-null  object
#  10  termdate        3929 non-null   object
#  11  location_city   22214 non-null  object
#  12  location_state  22214 non-null  object
# dtypes: object(13)
# memory usage: 2.4+ MB

# %%
df.isnull().sum()
# Out:
# id                    0
# first_name            0
# last_name             0
# birthdate             0
# gender                0
# race                  0
# department            0
# jobtitle              0
# location              0
# hire_date             0
# termdate          18285
# location_city         0
# location_state        0
# dtype: int64

# %%
df['full_name']= df['first_name']+" "+df['last_name']
df['term_date']=pd.to_datetime(df['termdate'])
df['hire_date']= pd.to_datetime(df['hire_date'])
df['birth_date']=pd.to_datetime(df['birthdate'])
df
# Out:
# C:\Users\97798\AppData\Local\Temp\ipykernel_10280\170907432.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['full_name']= df['first_name']+" "+df['last_name']
# C:\Users\97798\AppData\Local\Temp\ipykernel_10280\170907432.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['term_date']=pd.to_datetime(df['termdate'])
# C:\Users\97798\AppData\Local\Temp\ipykernel_10280\170907432.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
ndf=df

# %%
df.drop(columns=['termdate','birthdate','first_name','last_name'],axis=1,inplace=True)
df
# Out:
# C:\Users\97798\AppData\Local\Temp\ipykernel_10280\3316406136.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['termdate','birthdate','first_name','last_name'],axis=1,inplace=True)
#                id  gender                       race  \
# 0      00-0037846    Male         Hispanic or Latino
# 1      00-0041533    Male                      White
# 2      00-0045747    Male  Black or African American
# 3      00-0055274  Female                      White
# 4      00-0076100  Female          Two or More Races
# ...           ...     ...                        ...
# 22209  99-9797418  Female         Hispanic or Latino
# 22210  99-9869877  Female          Two or More Races
# 22211  99-9919822  Female          Two or More Races
# ...

# %%
ndf=df

# %%
ndf.head()
# Out:
#            id  gender                       race            department  \
# 0  00-0037846    Male         Hispanic or Latino           Engineering
# 1  00-0041533    Male                      White  Business Development
# 2  00-0045747    Male  Black or African American                 Sales
# 3  00-0055274  Female                      White              Services
# 4  00-0076100  Female          Two or More Races    Product Management
#
#                      jobtitle      location  hire_date location_city  \
# 0        Programmer Analyst I  Headquarters 2002-01-20     Cleveland
# 1            Business Analyst  Headquarters 2019-04-08     Cleveland
# 2  Solutions Engineer Manager  Headquarters 2010-10-12     Cleveland
# 3                Service Tech  Headquarters 2005-04-10     Cleveland
# 4            Business Analyst        Remote 2010-09-29         Flint
#
#   location_state           full_name                 term_date birth_date
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22214 entries, 0 to 22213
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              22214 non-null  object
#  1   gender          22214 non-null  object
#  2   race            22214 non-null  object
#  3   department      22214 non-null  object
#  4   jobtitle        22214 non-null  object
#  5   location        22214 non-null  object
#  6   hire_date       22214 non-null  datetime64[ns]
#  7   location_city   22214 non-null  object
#  8   location_state  22214 non-null  object
#  9   full_name       22214 non-null  object
#  10  term_date       3929 non-null   datetime64[ns, UTC]
#  11  birth_date      22214 non-null  datetime64[ns]
# dtypes: datetime64[ns, UTC](1), datetime64[ns](2), object(9)
# memory usage: 2.2+ MB

# %%
df['term date']= df['term_date']
df.head()
# Out:
# C:\Users\97798\AppData\Local\Temp\ipykernel_10280\53839316.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['term date']= df['term_date']
#            id  gender                       race            department  \
# 0  00-0037846    Male         Hispanic or Latino           Engineering
# 1  00-0041533    Male                      White  Business Development
# 2  00-0045747    Male  Black or African American                 Sales
# 3  00-0055274  Female                      White              Services
# 4  00-0076100  Female          Two or More Races    Product Management
#
#                      jobtitle      location  hire_date location_city  \
# 0        Programmer Analyst I  Headquarters 2002-01-20     Cleveland
# ...

# %%
df.drop(columns=['term date','term_date'],axis=1,inplace=True)
# Out:
# C:\Users\97798\AppData\Local\Temp\ipykernel_10280\1281082301.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(columns=['term date','term_date'],axis=1,inplace=True)

# %%
df.head()
# Out:
#            id  gender                       race            department  \
# 0  00-0037846    Male         Hispanic or Latino           Engineering
# 1  00-0041533    Male                      White  Business Development
# 2  00-0045747    Male  Black or African American                 Sales
# 3  00-0055274  Female                      White              Services
# 4  00-0076100  Female          Two or More Races    Product Management
#
#                      jobtitle      location  hire_date location_city  \
# 0        Programmer Analyst I  Headquarters 2002-01-20     Cleveland
# 1            Business Analyst  Headquarters 2019-04-08     Cleveland
# 2  Solutions Engineer Manager  Headquarters 2010-10-12     Cleveland
# 3                Service Tech  Headquarters 2005-04-10     Cleveland
# 4            Business Analyst        Remote 2010-09-29         Flint
#
#   location_state           full_name birth_date
# 0           Ohio    Kimmy Walczynski 1991-06-04
# ...

# %%
df=ndf

# %%
df
# Out:
#                id  gender                       race  \
# 0      00-0037846    Male         Hispanic or Latino
# 1      00-0041533    Male                      White
# 2      00-0045747    Male  Black or African American
# 3      00-0055274  Female                      White
# 4      00-0076100  Female          Two or More Races
# ...           ...     ...                        ...
# 22209  99-9797418  Female         Hispanic or Latino
# 22210  99-9869877  Female          Two or More Races
# 22211  99-9919822  Female          Two or More Races
# 22212  99-9960380    Male          Two or More Races
# 22213  99-9963543  Female                      White
#
#                      department                    jobtitle      location  \
# 0                   Engineering        Programmer Analyst I  Headquarters
# 1          Business Development            Business Analyst  Headquarters
# 2                         Sales  Solutions Engineer Manager  Headquarters
# ...

# %%
from datetime import date

# %%
df['today']=date.today()
# Out:
# C:\Users\97798\AppData\Local\Temp\ipykernel_10280\1330521394.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['today']=date.today()

# %%
df
# Out:
#                id  gender                       race  \
# 0      00-0037846    Male         Hispanic or Latino
# 1      00-0041533    Male                      White
# 2      00-0045747    Male  Black or African American
# 3      00-0055274  Female                      White
# 4      00-0076100  Female          Two or More Races
# ...           ...     ...                        ...
# 22209  99-9797418  Female         Hispanic or Latino
# 22210  99-9869877  Female          Two or More Races
# 22211  99-9919822  Female          Two or More Races
# 22212  99-9960380    Male          Two or More Races
# 22213  99-9963543  Female                      White
#
#                      department                    jobtitle      location  \
# 0                   Engineering        Programmer Analyst I  Headquarters
# 1          Business Development            Business Analyst  Headquarters
# 2                         Sales  Solutions Engineer Manager  Headquarters
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22214 entries, 0 to 22213
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              22214 non-null  object
#  1   gender          22214 non-null  object
#  2   race            22214 non-null  object
#  3   department      22214 non-null  object
#  4   jobtitle        22214 non-null  object
#  5   location        22214 non-null  object
#  6   hire_date       22214 non-null  datetime64[ns]
#  7   location_city   22214 non-null  object
#  8   location_state  22214 non-null  object
#  9   full_name       22214 non-null  object
#  10  birth_date      22214 non-null  datetime64[ns]
#  11  today           22214 non-null  object
# dtypes: datetime64[ns](2), object(10)
# memory usage: 2.2+ MB

# %%
df['today']=pd.to_datetime(df['today'])
# Out:
# C:\Users\97798\AppData\Local\Temp\ipykernel_10280\43109666.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['today']=pd.to_datetime(df['today'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22214 entries, 0 to 22213
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              22214 non-null  object
#  1   gender          22214 non-null  object
#  2   race            22214 non-null  object
#  3   department      22214 non-null  object
#  4   jobtitle        22214 non-null  object
#  5   location        22214 non-null  object
#  6   hire_date       22214 non-null  datetime64[ns]
#  7   location_city   22214 non-null  object
#  8   location_state  22214 non-null  object
#  9   full_name       22214 non-null  object
#  10  birth_date      22214 non-null  datetime64[ns]
#  11  today           22214 non-null  datetime64[ns]
# dtypes: datetime64[ns](3), object(9)
# memory usage: 2.2+ MB

# %%
df['age']=df['today'].dt.year-df['birth_date'].dt.year 
df
# Out:
# C:\Users\97798\AppData\Local\Temp\ipykernel_10280\4290607912.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['age']=df['today'].dt.year-df['birth_date'].dt.year
#                id  gender                       race  \
# 0      00-0037846    Male         Hispanic or Latino
# 1      00-0041533    Male                      White
# 2      00-0045747    Male  Black or African American
# 3      00-0055274  Female                      White
# 4      00-0076100  Female          Two or More Races
# ...           ...     ...                        ...
# 22209  99-9797418  Female         Hispanic or Latino
# 22210  99-9869877  Female          Two or More Races
# 22211  99-9919822  Female          Two or More Races
# ...

# %%
df['work years']=df['today'].dt.year-df['hire_date'].dt.year
# Out:
# C:\Users\97798\AppData\Local\Temp\ipykernel_10280\2359797503.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['work years']=df['today'].dt.year-df['hire_date'].dt.year

# %%
df
# Out:
#                id  gender                       race  \
# 0      00-0037846    Male         Hispanic or Latino
# 1      00-0041533    Male                      White
# 2      00-0045747    Male  Black or African American
# 3      00-0055274  Female                      White
# 4      00-0076100  Female          Two or More Races
# ...           ...     ...                        ...
# 22209  99-9797418  Female         Hispanic or Latino
# 22210  99-9869877  Female          Two or More Races
# 22211  99-9919822  Female          Two or More Races
# 22212  99-9960380    Male          Two or More Races
# 22213  99-9963543  Female                      White
#
#                      department                    jobtitle      location  \
# 0                   Engineering        Programmer Analyst I  Headquarters
# 1          Business Development            Business Analyst  Headquarters
# 2                         Sales  Solutions Engineer Manager  Headquarters
# ...

# %%
df
# Out:
#                id  gender                       race  \
# 0      00-0037846    Male         Hispanic or Latino
# 1      00-0041533    Male                      White
# 2      00-0045747    Male  Black or African American
# 3      00-0055274  Female                      White
# 4      00-0076100  Female          Two or More Races
# ...           ...     ...                        ...
# 22209  99-9797418  Female         Hispanic or Latino
# 22210  99-9869877  Female          Two or More Races
# 22211  99-9919822  Female          Two or More Races
# 22212  99-9960380    Male          Two or More Races
# 22213  99-9963543  Female                      White
#
#                      department                    jobtitle      location  \
# 0                   Engineering        Programmer Analyst I  Headquarters
# 1          Business Development            Business Analyst  Headquarters
# 2                         Sales  Solutions Engineer Manager  Headquarters
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 22214 entries, 0 to 22213
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              22214 non-null  object
#  1   gender          22214 non-null  object
#  2   race            22214 non-null  object
#  3   department      22214 non-null  object
#  4   jobtitle        22214 non-null  object
#  5   location        22214 non-null  object
#  6   hire_date       22214 non-null  datetime64[ns]
#  7   location_city   22214 non-null  object
#  8   location_state  22214 non-null  object
#  9   full_name       22214 non-null  object
#  10  birth_date      22214 non-null  datetime64[ns]
#  11  today           22214 non-null  datetime64[ns]
#  12  age             22214 non-null  int64
#  13  work years      22214 non-null  int64
# dtypes: datetime64[ns](3), int64(2), object(9)
# memory usage: 2.5+ MB

# %%
df['jobtitle'].unique().sum()
# Out:
# 'Programmer Analyst IBusiness AnalystSolutions Engineer ManagerService TechDeveloper IIIQuality EngineerDeveloper IBusiness Systems Development AnalystWeb Developer IService Tech IIResearch Assistant IIAnalyst ProgrammerStaff Accountant IIISoftware Engineer ISenior AttorneyData Visualization SpecialistSenior EditorSoftware ConsultantFinancial AnalystService ManagerSenior RecruiterHR ManagerTrainer IIIProgrammer IIITraining ManagerPre-Sales ConsultantData CoordiatorAdministrative Assistant IIRelationshiop ManagerHuman Resources AnalystDesktop Support TechnicianOperatorTax AccountantService Tech IIISenior DeveloperService CoordinatorSenior TrainerResearch Assistant ISupport Staff IISystems Administrator IContent Developer IIIInternal AuditorAdministrative OfficerAssistant TrainerTrainer IIRecruiterSupport StaffResearch AssociateSenior Quality EngineerCustomer Success ManagerHelp Desk TechnicianAccounting Assistant IIIStaff Accountant ISoftware Engineer IIISolutions EngineerAdministrati
# ...

# %%
df.to_csv('Human_resourse.csv',index=False)
